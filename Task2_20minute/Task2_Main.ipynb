# %%
import pandas as pd;
import datetime as dt;
import numpy as np;
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import scale
import pickle
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor

# %%
training = pd.read_csv('training2.csv')
del training['time']


X = training.iloc[:, :-1]
y = training.iloc[:, -1:]

X_max = X.max()
X = X / X_max

# y_max = y.max()
# y = y / y_max

#NN

hl = [40, 30, 20]
reg = MLPRegressor(\
                   solver='adam',\
                   hidden_layer_sizes = hl,\
                   max_iter = 200000,\
                   learning_rate = 'adaptive',\
                   learning_rate_init = 0.1,\
                   activation = 'relu') 
reg.fit(X, y)

# Xgb
xgb_model = xgb.XGBRegressor(max_depth=5, n_estimators=50, min_child_weight=1, gamma=0.9).fit(X,y)
# Out:
# C:\Users\Eric\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:1266: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
submission = pd.read_csv('submission2.csv')
submission_ori = submission.copy()
del submission['time_window']
del submission['volume']

X_submission = submission[X.columns] / X_max
submission_ori['volume'] = xgb_model.predict(X_submission)# * y_max[0]
submission['volume'] = submission_ori['volume']
submission_ori = submission_ori[submission_ori.columns[0:4]]
submission_ori.to_csv('submission2_result.csv', index=False)

# %%
training[\
         (training['tollgate_id'] == 1) & \
         (training['direction'] == 0) & \
         (training['week'] == 0) & \
         (training['hour'] == 17) & \
         (training['minute'] == 0)\
        ]
# Out:
#       tollgate_id  direction  week  hour  minute  pressure  sea_pressure  \
# 242           1.0        0.0   0.0  17.0     0.0    1011.1        1016.1
# 2680          1.0        0.0   0.0  17.0     0.0    1005.7        1010.6
# 7045          1.0        0.0   0.0  17.0     0.0    1014.0        1019.0
#
#       wind_direction  wind_speed  temperature  rel_humidity  precipitation  \
# 242            333.0         2.4         20.2          75.0            0.0
# 2680            46.0         1.3         24.7          92.0            0.0
# 7045           341.0         1.5         19.1          92.0            0.0
#
#       count
# 242    36.0
# 2680   47.0
# 7045   43.0

# %%
submission
# Out:
#      tollgate_id  direction  pressure  sea_pressure  wind_direction  \
# 0            1.0        0.0    1011.3        1016.3             7.0
# 1            1.0        0.0    1011.3        1016.3             7.0
# 2            1.0        0.0    1011.3        1016.3             7.0
# 3            1.0        0.0    1011.3        1016.3             7.0
# 4            1.0        0.0    1011.3        1016.3             7.0
# 5            1.0        0.0    1011.3        1016.3             7.0
# 6            1.0        1.0    1011.3        1016.3             7.0
# 7            1.0        1.0    1011.3        1016.3             7.0
# 8            1.0        1.0    1011.3        1016.3             7.0
# 9            1.0        1.0    1011.3        1016.3             7.0
# 10           1.0        1.0    1011.3        1016.3             7.0
# 11           1.0        1.0    1011.3        1016.3             7.0
# 12           2.0        0.0    1011.3        1016.3             7.0
# 13           2.0        0.0    1011.3        1016.3             7.0
# 14           2.0        0.0    1011.3        1016.3             7.0
# 15           2.0        0.0    1011.3        1016.3             7.0
# 16           2.0        0.0    1011.3        1016.3             7.0
# 17           2.0        0.0    1011.3        1016.3             7.0
# 18           3.0        0.0    1011.3        1016.3             7.0
# 19           3.0        0.0    1011.3        1016.3             7.0
# 20           3.0        0.0    1011.3        1016.3             7.0
# 21           3.0        0.0    1011.3        1016.3             7.0
# 22           3.0        0.0    1011.3        1016.3             7.0
# 23           3.0        0.0    1011.3        1016.3             7.0
# 24           3.0        1.0    1011.3        1016.3             7.0
# 25           3.0        1.0    1011.3        1016.3             7.0
# 26           3.0        1.0    1011.3        1016.3             7.0
# 27           3.0        1.0    1011.3        1016.3             7.0
# 28           3.0        1.0    1011.3        1016.3             7.0
# 29           3.0        1.0    1011.3        1016.3             7.0
# ..           ...        ...       ...           ...             ...
# 390          1.0        0.0    1024.7        1029.9           360.0
# 391          1.0        0.0    1024.7        1029.9           360.0
# 392          1.0        0.0    1024.7        1029.9           360.0
# 393          1.0        0.0    1024.7        1029.9           360.0
# 394          1.0        0.0    1024.7        1029.9           360.0
# 395          1.0        0.0    1024.7        1029.9           360.0
# 396          1.0        1.0    1024.7        1029.9           360.0
# 397          1.0        1.0    1024.7        1029.9           360.0
# 398          1.0        1.0    1024.7        1029.9           360.0
# 399          1.0        1.0    1024.7        1029.9           360.0
# 400          1.0        1.0    1024.7        1029.9           360.0
# 401          1.0        1.0    1024.7        1029.9           360.0
# 402          2.0        0.0    1024.7        1029.9           360.0
# 403          2.0        0.0    1024.7        1029.9           360.0
# 404          2.0        0.0    1024.7        1029.9           360.0
# 405          2.0        0.0    1024.7        1029.9           360.0
# 406          2.0        0.0    1024.7        1029.9           360.0
# 407          2.0        0.0    1024.7        1029.9           360.0
# 408          3.0        0.0    1024.7        1029.9           360.0
# 409          3.0        0.0    1024.7        1029.9           360.0
# 410          3.0        0.0    1024.7        1029.9           360.0
# 411          3.0        0.0    1024.7        1029.9           360.0
# 412          3.0        0.0    1024.7        1029.9           360.0
# 413          3.0        0.0    1024.7        1029.9           360.0
# 414          3.0        1.0    1024.7        1029.9           360.0
# 415          3.0        1.0    1024.7        1029.9           360.0
# 416          3.0        1.0    1024.7        1029.9           360.0
# 417          3.0        1.0    1024.7        1029.9           360.0
# 418          3.0        1.0    1024.7        1029.9           360.0
# 419          3.0        1.0    1024.7        1029.9           360.0
#
#      wind_speed  temperature  rel_humidity  precipitation  week  hour  minute  \
# 0           3.8         18.0          81.0            0.0   1.0   8.0     0.0
# 1           3.8         18.0          81.0            0.0   1.0   8.0    20.0
# 2           3.8         18.0          81.0            0.0   1.0   8.0    40.0
# 3           3.8         18.0          81.0            0.0   1.0   9.0     0.0
# 4           3.8         18.0          81.0            0.0   1.0   9.0    20.0
# 5           3.8         18.0          81.0            0.0   1.0   9.0    40.0
# 6           3.8         18.0          81.0            0.0   1.0   8.0     0.0
# 7           3.8         18.0          81.0            0.0   1.0   8.0    20.0
# 8           3.8         18.0          81.0            0.0   1.0   8.0    40.0
# 9           3.8         18.0          81.0            0.0   1.0   9.0     0.0
# 10          3.8         18.0          81.0            0.0   1.0   9.0    20.0
# 11          3.8         18.0          81.0            0.0   1.0   9.0    40.0
# 12          3.8         18.0          81.0            0.0   1.0   8.0     0.0
# 13          3.8         18.0          81.0            0.0   1.0   8.0    20.0
# 14          3.8         18.0          81.0            0.0   1.0   8.0    40.0
# 15          3.8         18.0          81.0            0.0   1.0   9.0     0.0
# 16          3.8         18.0          81.0            0.0   1.0   9.0    20.0
# 17          3.8         18.0          81.0            0.0   1.0   9.0    40.0
# 18          3.8         18.0          81.0            0.0   1.0   8.0     0.0
# 19          3.8         18.0          81.0            0.0   1.0   8.0    20.0
# 20          3.8         18.0          81.0            0.0   1.0   8.0    40.0
# 21          3.8         18.0          81.0            0.0   1.0   9.0     0.0
# 22          3.8         18.0          81.0            0.0   1.0   9.0    20.0
# 23          3.8         18.0          81.0            0.0   1.0   9.0    40.0
# 24          3.8         18.0          81.0            0.0   1.0   8.0     0.0
# 25          3.8         18.0          81.0            0.0   1.0   8.0    20.0
